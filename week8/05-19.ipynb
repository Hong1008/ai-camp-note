# %%
# 라이브러리 로드
import torch
import ultralytics
from ultralytics import  YOLO
from pathlib import Path
from PIL import Image
from config import CONTENT_DIR

# %%
model = YOLO('yolo11n.pt')

result1 = model(str( Path(CONTENT_DIR / '냉장고.jpg')))

result1[0].show()
# Out:
# image 1/1 /home/hong/project/ai-camp-note/content/냉장고.jpg: 640x480 5 bottles, 2 bowls, 1 refrigerator, 290.6ms
# Speed: 3.6ms preprocess, 290.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=1050x1400>
